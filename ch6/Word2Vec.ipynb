# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('ggplot')

# %%
from gensim.models import word2vec

# 単語データからモデルを生成
persons = ['夏目漱石', '太宰治', '芥川龍之介']
for person in persons:
    print(person)
    data = word2vec.LineSentence('text/'+person+'.wakati')
    model = word2vec.Word2Vec(data, size=2,
        window=3, hs=1, min_count=1, sg=1)
    model.save('text/2d-'+person+'.model')
print("ok")
# Out:
# 夏目漱石
# 太宰治
# 芥川龍之介
# ok

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec.load('text/2d-夏目漱石.model')

# %%
model["猫"]
# Out:
# array([-1.42065334, -0.22856641], dtype=float32)

# %%
import pandas as pd
dd = pd.DataFrame([
        model['父'],
        model['母'],
        model['男'],
        model['女'],
        model['猫'],
        model['犬'],
        model['人生'],
        model['恋愛']
    ], columns=['ax','ay'])
a = dd.plot.scatter(x='ax',y='ay',color='DarkBlue')
label = ['father','mother', 'man', 'woman','cat','dog','life','love']
for i, v in dd.iterrows():
    a.annotate(label[i], xy=(v[0],v[1]), size=9)

# %%
dd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b064a020db80> in <module>()
# ----> 1 dd
#
# NameError: name 'dd' is not defined

# %%
model.most_similar(positive=["猫",'女'],negative=["男"],topn=3)
# Out:
# [('露命', 1.0), ('Ｚ', 1.0), ('山県', 1.0)]

# %%
from gensim.models import word2vec
m = word2vec.Word2Vec.load('kokoro.model')
res = m.most_similar(positive=['海'],topn=10)
dd = pd.DataFrame(res, columns=['語句','rate'])
dd = dd.sort_values(by=["rate"], ascending=True)
p = dd.plot.barh(x="語句",y="rate",legend=False,xlim=[0.91,1])
print(res)
# Out:
# [('水', 0.9576714634895325), ('射す', 0.9574474692344666), ('広い', 0.9527318477630615), ('上がる', 0.9458383917808533), ('波', 0.9437301754951477), ('下', 0.9432513117790222), ('入れる', 0.9415151476860046), ('西洋', 0.9393413662910461), ('着る', 0.9322389364242554), ('帯', 0.9320167899131775)]

# %%
m = word2vec.Word2Vec.load('kokoro.model')
r = m.most_similar(positive=['人間'])
print(r)
dd = pd.DataFrame(r, columns=['語句','rate'])
dd = dd.sort_values(by=["rate"], ascending=True)
p = dd.plot.barh(x="語句",y="rate",legend=False,xlim=[0.8,1])
# Out:
# [('己', 0.9187383651733398), ('世の中', 0.9034476280212402), ('信用', 0.8888152837753296), ('悪人', 0.8875410556793213), ('事実', 0.886962354183197), ('いえる', 0.876944899559021), ('考え', 0.8750784397125244), ('変化', 0.8743740320205688), ('経験', 0.872992217540741), ('恋', 0.8677136301994324)]

# %%
fonts
# Out:
# ['/System/Library/Fonts/LastResort.ttf',
#  '/Library/Fonts/Microsoft/Calibri.ttf',
#  '/Library/Fonts/Microsoft/MS Mincho.ttf',
#  '/Library/Fonts/Microsoft/MS PMincho.ttf',
#  '/System/Library/Fonts/SFNSTextCondensed-Heavy.otf',
#  '/Library/Fonts/Diwan Thuluth.ttf',
#  '/Library/Fonts/Arial Narrow Bold.ttf',
#  '/Library/Fonts/Microsoft/Batang.ttf',
#  '/Library/Fonts/Microsoft/Lucida Sans Unicode.ttf',
#  '/System/Library/Fonts/SFNSTextCondensed-Medium.otf',
#  '/Library/Fonts/Skia.ttf',
#  '/Library/Fonts/Microsoft/MS Reference Sans Serif.ttf',
#  '/Library/Fonts/Arial Rounded Bold.ttf',
#  '/Library/Fonts/Microsoft/Perpetua Bold Italic.ttf',
#  '/Library/Fonts/Microsoft/Perpetua Bold.ttf',
#  '/System/Library/Fonts/Keyboard.ttf',
#  '/Library/Fonts/STIXVarBol.otf',
#  '/Library/Fonts/Lao Sangam MN.ttf',
#  '/Library/Fonts/Microsoft/Palatino Linotype Italic.ttf',
#  '/Library/Fonts/STIXIntUpDReg.otf',
#  '/System/Library/Fonts/SFCompactDisplay-Regular.otf',
# ...

# %%
import matplotlib.font_manager as fm
fm.findSystemFonts()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ['/Library/Fonts/Trebuchet MS Bold.ttf',
#  '/System/Library/Fonts/SFCompactText-MediumItalic.otf',
#  '/Library/Fonts/Microsoft/Verdana Italic.ttf',
#  '/Library/Fonts/Microsoft/Candara Bold.ttf',
#  '/Library/Fonts/Microsoft/Wingdings.ttf',
#  '/Library/Fonts/Microsoft/Wingdings 2.ttf',
#  '/System/Library/Fonts/SFCompactRounded-Black.otf',
#  '/Library/Fonts/Wingdings 2.ttf',
#  '/Library/Fonts/Microsoft/Perpetua Bold.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Semibold.otf',
#  '/Library/Fonts/Diwan Thuluth.ttf',
#  '/System/Library/Fonts/SFCompactText-BoldItalic.otf',
#  '/Library/Fonts/AppleGothic.ttf',
#  '/Library/Fonts/Microsoft/mingliu_hkscs.ttf',
# ...

# %%
plt.rcParams.get('font.family')
# Out:
# ['Sazanami Gothic']

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec.load('text/2d-夏目漱石.model')
model["猫"]
model

# %%
import pandas as pd
r = []
labels = []
for w in ["男","女","愛","人生","父","母","犬","猫"]:
    r.append(model[w])
    labels.append(w)
dd = pd.DataFrame(r,columns=['x','y'])
a = dd.plot.scatter(x='x',y='y',color='#ff9090',fontsize=9)
for i, v in dd.iterrows():
    a.annotate(labels[i], xy=(v[0],v[1]), size=12)

# %%
import matplotlib.font_manager as fm
fonts = fm.findSystemFonts()
for i in fonts:
    try:
        prop = font_manager.FontProperties(fname=i)
        print(prop.get_name())
    except:
        print("***")
# Out:
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ...

# %%
model.vocab['先生'].count
# Out:
# 597

# %%
import pandas as pd
r = []
labels = []
for w in ["男","女","愛","人生","父","母","犬","猫"]:
    r.append(model[w])
    labels.append(w)
dd = pd.DataFrame(r,columns=['x','y'])
a = dd.plot.scatter(x='x',y='y',color='#ff9090',fontsize=9)
for i, v in dd.iterrows():
    a.annotate(labels[i], xy=(v[0],v[1]), size=12)

# %%
# 2d の「こころ」を作る
from gensim.models import word2vec
data = word2vec.LineSentence("kokoro.wakati")
model = word2vec.Word2Vec(data, 
    size=2, window=3, hs=1, min_count=10, sg=1)
model.save('kokoro-2d.model')

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec.load('kokoro-2d.model')
model["先生"]
# Out:
# array([ 1.03366673, -0.53800029], dtype=float32)

# %%
import pandas as pd
plt.figure(figsize=(20,10))

r = []
labels = []
for w in model.vocab.keys():
    if model.vocab[w].count < 10: continue
    r.append(model[w])
    labels.append(w)
dd = pd.DataFrame(r,columns=['x','y'])
a = dd.plot.scatter(x='x',y='y',color='#ff9090',fontsize=9)
for i, v in dd.iterrows():
    a.annotate(labels[i], xy=(v[0],v[1]), size=6)

plt.savefig('test.png')

# %%
model.plot('先生')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-1e48cf74faf1> in <module>()
# ----> 1 model.plot('先生')
#
# AttributeError: 'Word2Vec' object has no attribute 'plot'

# %%
model = word2vec.Word2Vec.load('/Users/kujira/Desktop/jawiki/wiki.model')

# %%
model.most_similar(positive='Python')
# Out:
# [('Perl', 0.9422299861907959),
#  ('Java', 0.902813196182251),
#  ('JavaScript', 0.8997002840042114),
#  ('Haskell', 0.894286572933197),
#  ('Lua', 0.8877376317977905),
#  ('Ruby', 0.8861909508705139),
#  ('Smalltalk', 0.8846708536148071),
#  ('Lisp', 0.8819193840026855),
#  ('Emacs', 0.8796795010566711),
#  ('Erlang', 0.8695290088653564)]

# %%
dd = pd.DataFrame(model.most_similar(positive=['岡村'],topn=10), columns=['語句','rate'])
dd = dd.sort_values(by=["rate"], ascending=True)
p = dd.plot.barh(x="語句",y="rate",legend=False,xlim=[0.5,1])
